# %% [markdown]
# # QC notebook
#
# Quality control workflow for the sample bundle.

# %% [markdown]
# ## Filters
#
# We drop cells with fewer than 500 reads.

# %%
def filter_cells(adata, min_reads=500):
    return adata[adata.obs['total_counts'] >= min_reads]
